# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
df.head()
# Out:
#    Sno Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 0    1      M   67.00    Others   91.00    Others    Commerce     58.00
# 1    2      M   79.33   Central   78.33    Others     Science     77.48
# 2    3      M   65.00   Central   68.00   Central        Arts     64.00
# 3    4      M   56.00   Central   52.00   Central     Science     52.00
# 4    5      M   85.80   Central   73.60   Central    Commerce     73.30
#
#   Degree stream Work exp specialisation  Mba %      status    salary
# 0      Sci&Tech       No         Mkt&HR  58.80      Placed  270000.0
# 1      Sci&Tech      Yes        Mkt&Fin  66.28      Placed  200000.0
# 2     Comm&Mgmt       No        Mkt&Fin  57.80      Placed  250000.0
# 3      Sci&Tech       No         Mkt&HR  59.43  Not Placed       NaN
# 4     Comm&Mgmt       No        Mkt&Fin  55.50      Placed  425000.0

# %%
df.tail()
# Out:
#      Sno Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 210  211      M    80.6    Others    82.0    Others    Commerce      77.6
# 211  212      M    58.0    Others    60.0    Others     Science      72.0
# 212  213      M    67.0    Others    67.0    Others    Commerce      73.0
# 213  214      F    74.0    Others    66.0    Others    Commerce      58.0
# 214  215      M    62.0   Central    58.0    Others     Science      53.0
#
#     Degree stream Work exp specialisation  Mba %      status    salary
# 210     Comm&Mgmt       No        Mkt&Fin  74.49      Placed  400000.0
# 211      Sci&Tech       No        Mkt&Fin  53.62      Placed  275000.0
# 212     Comm&Mgmt      Yes        Mkt&Fin  69.72      Placed  295000.0
# 213     Comm&Mgmt       No         Mkt&HR  60.23      Placed  204000.0
# 214     Comm&Mgmt       No         Mkt&HR  60.22  Not Placed       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sno             215 non-null    int64
#  1   Gender          215 non-null    object
#  2   10th %          215 non-null    float64
#  3   SSC Board       215 non-null    object
#  4   12th %          215 non-null    float64
#  5   HSC Board       215 non-null    object
#  6   12th Stream     215 non-null    object
#  7   Degree %        215 non-null    float64
#  8   Degree stream   215 non-null    object
#  9   Work exp        215 non-null    object
#  10  specialisation  215 non-null    object
#  11  Mba %           215 non-null    float64
#  12  status          215 non-null    object
#  13  salary          148 non-null    float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 23.6+ KB

# %%
df.shape
# Out:
# (215, 14)

# %%
df.describe()
# Out:
#               Sno      10th %      12th %    Degree %       Mba %  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   62.278186
# std     62.209324   10.827205   10.897509    7.358743    5.833385
# min      1.000000   40.890000   37.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.describe(include="object")
# Out:
#        Gender SSC Board HSC Board 12th Stream Degree stream Work exp  \
# count     215       215       215         215           215      215
# unique      2         2         2           3             3        2
# top         M   Central    Others    Commerce     Comm&Mgmt       No
# freq      139       116       131         113           145      141
#
#        specialisation  status
# count             215     215
# unique              2       2
# top           Mkt&Fin  Placed
# freq              120     148

# %%
df.isnull().sum()
# Out:
# Sno                0
# Gender             0
# 10th %             0
# SSC Board          0
# 12th %             0
# HSC Board          0
# 12th Stream        0
# Degree %           0
# Degree stream      0
# Work exp           0
# specialisation     0
# Mba %              0
# status             0
# salary            67
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=["Sno"],inplace=True)

# %%
df.sample(5)
# Out:
#     Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 181      M   62.00   Central   60.33    Others     Science     64.21
# 184      F   56.28    Others   62.83    Others    Commerce     59.79
# 98       F   69.00   Central   73.00   Central    Commerce     65.00
# 185      F   88.00   Central   72.00   Central     Science     78.00
# 18       F   63.00   Central   66.00   Central    Commerce     64.00
#
#     Degree stream Work exp specialisation  Mba %      status    salary
# 181      Sci&Tech       No         Mkt&HR  60.02  Not Placed       NaN
# 184     Comm&Mgmt       No         Mkt&HR  57.29  Not Placed       NaN
# 98      Comm&Mgmt       No        Mkt&Fin  57.31      Placed  220000.0
# 185        Others       No         Mkt&HR  71.43      Placed  252000.0
# 18      Comm&Mgmt       No         Mkt&HR  64.08  Not Placed       NaN

# %%
df.dtypes
# Out:
# Gender             object
# 10th %            float64
# SSC Board          object
# 12th %            float64
# HSC Board          object
# 12th Stream        object
# Degree %          float64
# Degree stream      object
# Work exp           object
# specialisation     object
# Mba %             float64
# status             object
# salary            float64
# dtype: object

# %% [markdown]
# # Now we will Peform EDA

# %%
df.boxplot(figsize=(10,5))
plt.show()

# %%
sns.scatterplot(df,x=df["12th %"],y=df["10th %"])
plt.show()

# %%
sns.barplot(x=df["status"], y=df["10th %"])  # Use the actual column name for "10th %"
plt.xlabel("Placement Status")
plt.ylabel("10th Percentage")
plt.title("10th Percentage vs Placement Status")
plt.show()

# %%
a=sns.barplot(x=df["status"], y=df["12th %"]) # Use the actual column name for "12th %"
a.bar_label(a.containers[0])
plt.xlabel("Placement Status")
plt.ylabel("12th Percentage")
plt.title("12th Percentage vs Placement Status")
plt.show()

# %%
ax=sns.countplot(x=df["status"]) # Use the actual column name for "10th %"
ax.bar_label(ax.containers[0])
plt.show()

# %%
b=sns.barplot(x=df["status"], y=df["Degree %"]) # Use the actual column name for "12th %"
b.bar_label(b.containers[0])
plt.xlabel("Placement Status")
plt.ylabel("Degree Percentage")
plt.title("Degree Percentage vs Placement Status")
plt.show()

# %%
c=sns.barplot(x=df["status"], y=df["Mba %"]) # Use the actual column name for "12th %"
c.bar_label(c.containers[0])
plt.xlabel("Placement Status")
plt.ylabel("Degree Percentage")
plt.title("Degree Percentage vs Placement Status")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder


# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding
df["status"] = label_encoder.fit_transform(df["status"])

df
# Out:
#     Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 0        M   67.00    Others   91.00    Others    Commerce     58.00
# 1        M   79.33   Central   78.33    Others     Science     77.48
# 2        M   65.00   Central   68.00   Central        Arts     64.00
# 3        M   56.00   Central   52.00   Central     Science     52.00
# 4        M   85.80   Central   73.60   Central    Commerce     73.30
# ..     ...     ...       ...     ...       ...         ...       ...
# 210      M   80.60    Others   82.00    Others    Commerce     77.60
# 211      M   58.00    Others   60.00    Others     Science     72.00
# 212      M   67.00    Others   67.00    Others    Commerce     73.00
# 213      F   74.00    Others   66.00    Others    Commerce     58.00
# 214      M   62.00   Central   58.00    Others     Science     53.00
#
#     Degree stream Work exp specialisation  Mba %  status    salary
# 0        Sci&Tech       No         Mkt&HR  58.80       1  270000.0
# ...

# %%
# Initialize one hot encoding
pd.get_dummies(df,columns=['specialisation'])
# Out:
#      10th %  SSC Board  12th %  Degree %  Mba %  status  specialisation_0  \
# 0     67.00          1   91.00     58.00  58.80       1             False
# 1     79.33          0   78.33     77.48  66.28       1              True
# 2     65.00          0   68.00     64.00  57.80       1              True
# 3     56.00          0   52.00     52.00  59.43       0             False
# 4     85.80          0   73.60     73.30  55.50       1              True
# ..      ...        ...     ...       ...    ...     ...               ...
# 210   80.60          1   82.00     77.60  74.49       1              True
# 211   58.00          1   60.00     72.00  53.62       1              True
# 212   67.00          1   67.00     73.00  69.72       1              True
# 213   74.00          1   66.00     58.00  60.23       1             False
# 214   62.00          0   58.00     53.00  60.22       0             False
#
#      specialisation_1
# 0                True
# 1               False
# ...

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding
df["SSC Board"] = label_encoder.fit_transform(df["SSC Board"])

df
# Out:
#      10th %  SSC Board  12th %  Degree %  specialisation  Mba %  status
# 0     67.00          1   91.00     58.00               1  58.80       1
# 1     79.33          0   78.33     77.48               0  66.28       1
# 2     65.00          0   68.00     64.00               0  57.80       1
# 3     56.00          0   52.00     52.00               1  59.43       0
# 4     85.80          0   73.60     73.30               0  55.50       1
# ..      ...        ...     ...       ...             ...    ...     ...
# 210   80.60          1   82.00     77.60               0  74.49       1
# 211   58.00          1   60.00     72.00               0  53.62       1
# 212   67.00          1   67.00     73.00               0  69.72       1
# 213   74.00          1   66.00     58.00               1  60.23       1
# 214   62.00          0   58.00     53.00               1  60.22       0
#
# [215 rows x 7 columns]

# %%
df.head()
# Out:
#    10th %  SSC Board  12th %  Degree %  specialisation  Mba %  status
# 0   67.00          1   91.00     58.00               1  58.80       1
# 1   79.33          0   78.33     77.48               0  66.28       1
# 2   65.00          0   68.00     64.00               0  57.80       1
# 3   56.00          0   52.00     52.00               1  59.43       0
# 4   85.80          0   73.60     73.30               0  55.50       1

# %%
df.tail()
# Out:
#      10th %  SSC Board  12th %  Degree %  specialisation  Mba %  status
# 210    80.6          1    82.0      77.6               0  74.49       1
# 211    58.0          1    60.0      72.0               0  53.62       1
# 212    67.0          1    67.0      73.0               0  69.72       1
# 213    74.0          1    66.0      58.0               1  60.23       1
# 214    62.0          0    58.0      53.0               1  60.22       0

# %%
df.head()
# Out:
#    10th %  SSC Board  12th %  Degree %  specialisation  Mba %  status
# 0   67.00          1   91.00     58.00               1  58.80       1
# 1   79.33          0   78.33     77.48               0  66.28       1
# 2   65.00          0   68.00     64.00               0  57.80       1
# 3   56.00          0   52.00     52.00               1  59.43       0
# 4   85.80          0   73.60     73.30               0  55.50       1

# %%
status_counts = df["status"].value_counts()

# %%
plt.pie(status_counts,autopct="%1.1f%%")
plt.title("Percentge of student  placed")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   10th %          215 non-null    float64
#  1   SSC Board       215 non-null    int64
#  2   12th %          215 non-null    float64
#  3   Degree %        215 non-null    float64
#  4   specialisation  215 non-null    int64
#  5   Mba %           215 non-null    float64
#  6   status          215 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 11.9 KB

# %%
df = df.drop(columns=df.select_dtypes(include=['object']).columns)

# %%
df.head()
# Out:
#    10th %  SSC Board  12th %  Degree %  specialisation  Mba %  status
# 0   67.00          1   91.00     58.00               1  58.80       1
# 1   79.33          0   78.33     77.48               0  66.28       1
# 2   65.00          0   68.00     64.00               0  57.80       1
# 3   56.00          0   52.00     52.00               1  59.43       0
# 4   85.80          0   73.60     73.30               0  55.50       1

# %%
df.head()
# Out:
#    10th %  SSC Board  12th %  Degree %  specialisation  Mba %  status
# 0   67.00          1   91.00     58.00               1  58.80       1
# 1   79.33          0   78.33     77.48               0  66.28       1
# 2   65.00          0   68.00     64.00               0  57.80       1
# 3   56.00          0   52.00     52.00               1  59.43       0
# 4   85.80          0   73.60     73.30               0  55.50       1

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.get_dummies(df,columns=['specialisation'])

# %%
# Separate features (X) and target variable (y)
x = df.drop(columns=["status"])  # Assuming "status" is the target column
y = df["status"]
# Split into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#      10th %  SSC Board  12th %  Degree %  Mba %  specialisation_0  \
# 93    52.00          0    62.0      54.0  55.41             False
# 84    70.00          0    63.0      70.0  62.00              True
# 95    73.00          0    78.0      65.0  62.16              True
# 137   67.00          1    63.0      72.0  60.41             False
# 210   80.60          1    82.0      77.6  74.49              True
# ..      ...        ...     ...       ...    ...               ...
# 106   61.08          1    50.0      54.0  65.69              True
# 14    62.00          0    47.0      50.0  54.96             False
# 92    60.23          0    69.0      66.0  59.47              True
# 179   77.80          0    64.0      64.2  72.14             False
# 102   77.00          1    61.0      68.0  61.31              True
#
#      specialisation_1
# 93               True
# 84              False
# 95              False
# 137              True
# 210             False
# ..                ...
# ...

# %%
y_train
# Out:
# 93     0
# 84     1
# 95     1
# 137    1
# 210    1
#       ..
# 106    0
# 14     0
# 92     1
# 179    0
# 102    1
# Name: status, Length: 172, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(n_neighbors=5),
    
}

# %%
# 🔹 Train, Predict & Evaluate Models
for name, model in models.items():
    model.fit(x_train, y_train)  # Train Model
    y_pred = model.predict(x_test)  # Predict on Test Data
    
    # Accuracy & Classification Report
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\n🔹 {name} Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))
# Out:
# 🔹 Logistic Regression Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.85      0.94      0.89        31
#
#     accuracy                           0.84        43
#    macro avg       0.82      0.76      0.78        43
# weighted avg       0.83      0.84      0.83        43
#
#
# 🔹 Decision Tree Accuracy: 0.88
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78        12
#            1       0.91      0.94      0.92        31
#
#     accuracy                           0.88        43
#    macro avg       0.86      0.84      0.85        43
# weighted avg       0.88      0.88      0.88        43
#
#
# 🔹 Random Forest Accuracy: 0.81
#               precision    recall  f1-score   support
#
#            0       0.75      0.50      0.60        12
#            1       0.83      0.94      0.88        31
#
# ...

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 4  8]
#  [ 2 29]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44        12
#            1       0.78      0.94      0.85        31
#
#     accuracy                           0.77        43
#    macro avg       0.73      0.63      0.65        43
# weighted avg       0.75      0.77      0.74        43
